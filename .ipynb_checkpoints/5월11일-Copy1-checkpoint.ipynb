# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
input_shape = (28, 28, 1)
num_classes = 10

# %%
(x_train, y_train), (x_test, y_test) = datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
np.max(y_train)
# Out:
# np.uint8(9)

# %%
plt.imshow(x_train[2], 'gray')
plt.show()

# %%
def myModel(input_shape, num_classes):    
    inputs = layers.Input(shape=input_shape)
    net = layers.Conv2D(32, 3, 1, padding='same', activation='relu')(inputs)
    #net = layers.Conv2D(32, 3, 1, padding='same', activation='relu')(net)
    net = layers.MaxPool2D((2, 2))(net)
    
    net = layers.Conv2D(64, 3, 1, padding='same', activation='relu')(net)
    #net = layers.Conv2D(64, 3, 1, padding='same', activation='relu')(net)
    net = layers.MaxPool2D((2, 2))(net)
    
    net = layers.Flatten()(net)
    net = layers.Dense(512, activation='relu')(net)
    net = layers.Dense(num_classes, activation='softmax')(net)
    
    model = tf.keras.Model(inputs=inputs, outputs=net, name = 'TestModel') # 요거 이름 공란 있으면 밑에서 오류남 

    return model

# %%
model = myModel(input_shape, num_classes)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
x_train_4d = x_train[..., tf.newaxis] # 3D -> 4D
print(x_train_4d.shape, x_train.shape, x_train_4d.dtype)
x_train_4d = x_train_4d / 255.0 # scaling to [0,1]
print(np.max(x_train_4d), np.min(x_train_4d))
# Out:
# (60000, 28, 28, 1) (60000, 28, 28) uint8
# 1.0 0.0

# %%
x_test_4d = x_test[..., tf.newaxis] # 3D -> 4D
x_test_4d = x_test_4d / 255.0
print(x_test_4d.shape)
# Out:
# (10000, 28, 28, 1)

# %%
num_epochs = 10
bs = 32
hist = model.fit(x_train_4d, y_train, validation_data = (x_test_4d, y_test), batch_size=bs, shuffle=True, epochs=num_epochs)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8616 - loss: 0.3809 - val_accuracy: 0.8952 - val_loss: 0.2921
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9093 - loss: 0.2457 - val_accuracy: 0.9056 - val_loss: 0.2574
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9267 - loss: 0.2004 - val_accuracy: 0.9170 - val_loss: 0.2257
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9386 - loss: 0.1666 - val_accuracy: 0.9097 - val_loss: 0.2494
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9482 - loss: 0.1371 - val_accuracy: 0.9205 - val_loss: 0.2330
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9588 - loss: 0.1087 - val_accuracy: 0.9236 - val_loss: 0.2434
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9678 - loss: 0.0861 - val_accuracy: 0.9125 - val_loss: 0.3025
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9742 - loss: 0.0681 - val_accuracy: 0.9166 - val_loss: 0.3012
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9793 - loss: 0.0554 - val_accuracy: 0.9221 - val_loss: 0.3292
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9834 - loss: 0.0458 - val_accuracy: 0.9238 - val_loss: 0.3170

# %%
x_test[0:5].shape
# Out:
# (5, 28, 28)

# %%
pred = model.predict(x_test_4d[0:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
type(pred), pred.shape
# Out:
# (numpy.ndarray, (5, 10))

# %%
pred
# Out:
# array([[3.6753385e-11, 1.3492722e-09, 4.3189946e-10, 7.7851607e-11,
#         4.7891580e-11, 1.1113956e-09, 1.1497143e-10, 2.0784942e-07,
#         7.2667199e-11, 9.9999976e-01],
#        [1.2985765e-07, 5.0252948e-20, 9.9999988e-01, 1.7861115e-13,
#         2.9030930e-15, 8.4578903e-18, 3.7631985e-12, 1.2720085e-14,
#         1.9889183e-16, 2.6918817e-18],
#        [1.6838447e-16, 1.0000000e+00, 3.7994530e-17, 7.5792693e-16,
#         2.3892372e-18, 9.8826976e-25, 5.0356791e-19, 7.5063910e-30,
#         1.0933196e-22, 4.8546367e-28],
#        [1.2139837e-18, 1.0000000e+00, 2.5646315e-22, 7.6678572e-22,
#         1.6296793e-17, 1.3374535e-31, 5.0662531e-21, 5.6317854e-33,
#         5.5744111e-28, 4.5472128e-31],
#        [1.0031079e-01, 4.2949200e-13, 2.0402392e-04, 8.5897645e-09,
#         1.1305939e-05, 8.4238277e-10, 8.9947373e-01, 3.2913174e-08,
#         8.1277166e-11, 9.0079418e-08]], dtype=float32)

# %%
y_test[0:5], np.argmax(pred, axis=1)
# Out:
# (array([9, 2, 1, 1, 6], dtype=uint8), array([9, 2, 1, 1, 6]))

# %%
plt.imshow(x_test_4d[4].reshape(28, 28), 'gray')
plt.show()

# %%
pred = model.predict(x_test_4d)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
pred.shape
# Out:
# (10000, 10)

# %%
result = np.argmax(pred, axis=1)

# %%
result.shape
# Out:
# (10000,)

# %%
result, y_test
# Out:
# (array([9, 2, 1, ..., 8, 1, 5], shape=(10000,)),
#  array([9, 2, 1, ..., 8, 1, 5], shape=(10000,), dtype=uint8))

# %%
cmp = (result == y_test)

# %%
cmp
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], shape=(10000,))

# %%
cnt = np.sum(cmp)

# %%
print(cnt, cnt/y_test.shape[0])
# Out:
# 9238 0.9238

# %%
falseArray = []
for index, value in enumerate(cmp):
    if value==False:
        falseArray.append(index)

# %%
len(falseArray)
# Out:
# 762

# %%
falseArray
# Out:
# [23,
#  25,
#  40,
#  42,
#  48,
#  67,
#  68,
#  73,
#  74,
#  98,
#  147,
#  150,
#  151,
#  153,
#  217,
#  227,
#  239,
#  244,
#  266,
#  271,
#  316,
#  324,
#  325,
#  352,
#  374,
#  378,
#  381,
#  382,
#  389,
#  394,
#  396,
#  404,
#  441,
#  444,
#  460,
#  474,
#  491,
#  498,
#  510,
#  529,
#  536,
#  563,
#  628,
#  629,
#  635,
#  639,
#  655,
#  661,
#  669,
#  670,
#  674,
#  711,
#  716,
#  724,
#  732,
#  736,
#  753,
#  758,
#  760,
#  787,
#  799,
#  851,
#  877,
#  881,
#  893,
#  902,
#  905,
#  909,
#  910,
#  921,
#  930,
#  935,
#  937,
#  939,
#  960,
#  965,
#  977,
#  979,
#  997,
#  1000,
#  1005,
#  1025,
#  1028,
#  1055,
#  1104,
#  1111,
#  1129,
#  1131,
#  1139,
#  1142,
#  1147,
#  1160,
#  1165,
#  1191,
#  1197,
#  1210,
#  1223,
#  1231,
#  1234,
#  1254,
#  1280,
#  1300,
#  1305,
#  1329,
#  1336,
#  1353,
#  1356,
#  1376,
#  1385,
#  1387,
#  1396,
#  1408,
#  1425,
#  1449,
#  1452,
#  1469,
#  1482,
#  1509,
#  1527,
#  1528,
#  1533,
#  1572,
#  1617,
#  1620,
#  1625,
#  1640,
#  1643,
#  1645,
#  1650,
#  1661,
#  1682,
#  1710,
#  1731,
#  1743,
#  1744,
#  1753,
#  1810,
#  1822,
#  1836,
#  1846,
#  1878,
#  1922,
#  1942,
#  1943,
#  1945,
#  1953,
#  1964,
#  1968,
#  2001,
#  2006,
#  2022,
#  2037,
#  2048,
#  2057,
#  2063,
#  2064,
#  2106,
#  2136,
#  2144,
#  2148,
#  2195,
#  2236,
#  2245,
#  2252,
#  2278,
#  2280,
#  2305,
#  2308,
#  2311,
#  2318,
#  2326,
#  2331,
#  2337,
#  2352,
#  2355,
#  2396,
#  2425,
#  2431,
#  2455,
#  2462,
#  2469,
#  2476,
#  2479,
#  2485,
#  2491,
#  2506,
#  2507,
#  2509,
#  2540,
#  2548,
#  2551,
#  2580,
#  2589,
#  2593,
#  2595,
#  2599,
#  2615,
#  2617,
#  2626,
#  2628,
#  2653,
#  2681,
#  2684,
#  2713,
#  2717,
#  2721,
#  2758,
#  2764,
#  2779,
#  2817,
#  2839,
#  2840,
#  2842,
#  2843,
#  2856,
#  2860,
#  2894,
#  2897,
#  2898,
#  2900,
#  2905,
#  2909,
#  2914,
#  2918,
#  2919,
#  2920,
#  2940,
#  2942,
#  2953,
#  2979,
#  2985,
#  2986,
#  2991,
#  3008,
#  3019,
#  3038,
#  3084,
#  3096,
#  3123,
#  3132,
#  3167,
#  3176,
#  3181,
#  3187,
#  3188,
#  3190,
#  3198,
#  3203,
#  3209,
#  3224,
#  3229,
#  3232,
#  3240,
#  3258,
#  3262,
#  3269,
#  3284,
#  3297,
#  3322,
#  3323,
#  3334,
#  3338,
#  3351,
#  3370,
#  3401,
#  3429,
#  3436,
#  3441,
#  3450,
#  3451,
#  3457,
#  3466,
#  3476,
#  3481,
#  3488,
#  3489,
#  3496,
#  3499,
#  3531,
#  3532,
#  3534,
#  3540,
#  3553,
#  3554,
#  3568,
#  3588,
#  3606,
#  3609,
#  3613,
#  3614,
#  3615,
#  3625,
#  3639,
#  3669,
#  3681,
#  3706,
#  3731,
#  3741,
#  3745,
#  3787,
#  3800,
#  3804,
#  3816,
#  3829,
#  3830,
#  3864,
#  3865,
#  3880,
#  3909,
#  3919,
#  3932,
#  3937,
#  3938,
#  3953,
#  3955,
#  3983,
#  3987,
#  4021,
#  4037,
#  4041,
#  4061,
#  4067,
#  4082,
#  4084,
#  4101,
#  4104,
#  4106,
#  4140,
#  4142,
#  4143,
#  4148,
#  4152,
#  4153,
#  4159,
#  4166,
#  4187,
#  4193,
#  4213,
#  4217,
#  4231,
#  4233,
#  4250,
#  4251,
#  4267,
#  4271,
#  4272,
#  4280,
#  4289,
#  4292,
#  4305,
#  4327,
#  4333,
#  4388,
#  4417,
#  4422,
#  4433,
#  4460,
#  4462,
#  4469,
#  4481,
#  4490,
#  4526,
#  4539,
#  4542,
#  4559,
#  4568,
#  4570,
#  4599,
#  4608,
#  4624,
#  4672,
#  4674,
#  4685,
#  4692,
#  4693,
#  4694,
#  4705,
#  4711,
#  4727,
#  4734,
#  4738,
#  4746,
#  4751,
#  4782,
#  4784,
#  4803,
#  4817,
#  4823,
#  4828,
#  4846,
#  4850,
#  4882,
#  4886,
#  4907,
#  4916,
#  4920,
#  4922,
#  4924,
#  4934,
#  4941,
#  4956,
#  4965,
#  4995,
#  5006,
#  5025,
#  5030,
#  5032,
#  5041,
#  5052,
#  5065,
#  5066,
#  5070,
#  5101,
#  5108,
#  5121,
#  5123,
#  5144,
#  5155,
#  5167,
#  5173,
#  5178,
#  5186,
#  5197,
#  5207,
#  5228,
#  5244,
#  5249,
#  5255,
#  5259,
#  5266,
#  5297,
#  5299,
#  5304,
#  5316,
#  5334,
#  5336,
#  5381,
#  5391,
#  5424,
#  5429,
#  5445,
#  5470,
#  5471,
#  5510,
#  5512,
#  5520,
#  5521,
#  5522,
#  5533,
#  5568,
#  5569,
#  5576,
#  5587,
#  5592,
#  5594,
#  5601,
#  5623,
#  5648,
#  5655,
#  5657,
#  5661,
#  5672,
#  5674,
#  5695,
#  5701,
#  5703,
#  5713,
#  5719,
#  5721,
#  5734,
#  5735,
#  5760,
#  5777,
#  5806,
#  5820,
#  5881,
#  5885,
#  5907,
#  5927,
#  5938,
#  5939,
#  5946,
#  5967,
#  5971,
#  5974,
#  5987,
#  5993,
#  6007,
#  6008,
#  6061,
#  6065,
#  6094,
#  6096,
#  6103,
#  6127,
#  6147,
#  6159,
#  6162,
#  6169,
#  6175,
#  6201,
#  6241,
#  6248,
#  6252,
#  6254,
#  6258,
#  6262,
#  6280,
#  6293,
#  6331,
#  6335,
#  6344,
#  6363,
#  6365,
#  6377,
#  6379,
#  6402,
#  6404,
#  6418,
#  6420,
#  6433,
#  6434,
#  6444,
#  6464,
#  6472,
#  6485,
#  6531,
#  6539,
#  6542,
#  6558,
#  6559,
#  6576,
#  6584,
#  6593,
#  6596,
#  6614,
#  6625,
#  6626,
#  6646,
#  6654,
#  6676,
#  6688,
#  6689,
#  6701,
#  6709,
#  6721,
#  6733,
#  6751,
#  6762,
#  6796,
#  6809,
#  6826,
#  6829,
#  6832,
#  6855,
#  6861,
#  6866,
#  6899,
#  6908,
#  6926,
#  6957,
#  6958,
#  6964,
#  6984,
#  6990,
#  6997,
#  7026,
#  7028,
#  7049,
#  7068,
#  7073,
#  7103,
#  7130,
#  7134,
#  7167,
#  7177,
#  7188,
#  7189,
#  7195,
#  7214,
#  7221,
#  7258,
#  7278,
#  7283,
#  7299,
#  7314,
#  7369,
#  7405,
#  7416,
#  7442,
#  7445,
#  7446,
#  7507,
#  7526,
#  7533,
#  7591,
#  7596,
#  7635,
#  7664,
#  7720,
#  7755,
#  7761,
#  7768,
#  7769,
#  7778,
#  7798,
#  7800,
#  7816,
#  7818,
#  7847,
#  7868,
#  7883,
#  7890,
#  7899,
#  7924,
#  7936,
#  7941,
#  7948,
#  7962,
#  7976,
#  7986,
#  7992,
#  7998,
#  8005,
#  8014,
#  8031,
#  8035,
#  8054,
#  8064,
#  8069,
#  8110,
#  8111,
#  8121,
#  8132,
#  8142,
#  8154,
#  8202,
#  8226,
#  8227,
#  8237,
#  8259,
#  8260,
#  8280,
#  8292,
#  8296,
#  8298,
#  8324,
#  8341,
#  8348,
#  8373,
#  8399,
#  8404,
#  8457,
#  8463,
#  8525,
#  8532,
#  8538,
#  8569,
#  8580,
#  8598,
#  8607,
#  8617,
#  8618,
#  8621,
#  8645,
#  8646,
#  8658,
#  8664,
#  8669,
#  8688,
#  8695,
#  8705,
#  8706,
#  8714,
#  8717,
#  8725,
#  8745,
#  8757,
#  8763,
#  8764,
#  8768,
#  8784,
#  8804,
#  8806,
#  8818,
#  8832,
#  8834,
#  8869,
#  8877,
#  8879,
#  8896,
#  8914,
#  8919,
#  8939,
#  8952,
#  8954,
#  8958,
#  9017,
#  9032,
#  9033,
#  9094,
#  9095,
#  9122,
#  9126,
#  9133,
#  9140,
#  9149,
#  9154,
#  9197,
#  9204,
#  9211,
#  9218,
#  9235,
#  9237,
#  9247,
#  9251,
#  9256,
#  9276,
#  9291,
#  9292,
#  9325,
#  9340,
#  9398,
#  9441,
#  9449,
#  9487,
#  9502,
#  9521,
#  9554,
#  9574,
#  9582,
#  9601,
#  9602,
#  9604,
#  9634,
#  9661,
#  9662,
#  9687,
#  9690,
#  9692,
#  9701,
#  9705,
#  9714,
#  9719,
#  9724,
#  9729,
#  9743,
#  9748,
#  9750,
#  9795,
#  9835,
#  9846,
#  9880,
#  9904,
#  9945,
#  9946,
#  9947,
#  9951,
#  9953,
#  9969,
#  9972,
#  9977]

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
type(class_names[0])
# Out:
# str

# %%
index = 2
plt.imshow(x_test[falseArray[index]].reshape(28, 28), 'gray')
plt.title(str(y_test[falseArray[index]]) + class_names[y_test[falseArray[index]]] +
          ", " + str(result[falseArray[index]]) + class_names[y_test[falseArray[index]]])
plt.show()
