# %%
print('hello world') # my code
# 내 코드
# Out:
# hello world

# %% [markdown]
# # Markdown
# - 이 jupyter notebook은 **visual studio code**에서도 가상화를 이용하여 실행 할 수 있다 나중에 해보면 재미있으니 꼭해보도록
# ## Markdown
# ### Markdown
# #### Markdown
# - python
#     - pandas
#     - numpy
# - java
# 수식 예 $y = ax^2 + bx + c$ *수식 왠만해서 다 찾아보면 있다.*
#
# $\int_{0}^{1} x(t) dt$
#
# $\frac{a}{b+c}$
#
# ```python
# print('hello world')
# a = 100
# b = 200
# ```
# [정보통신공학부](https://inform.chungbuk.ac.kr/)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.21.0'

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('test.png',1)
cv2.imshow('HSKANG', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img)
#plt.show()

# %%
a = 10
b = 11.4

# %%
print(a, b)
print(a, 100, 200, b)
print(a, 100, 200, b, sep=', ', end='...\n')
# Out:
# 10 11.4
# 10 100 200 11.4
# 10, 100, 200, 11.4...

# %%
a, b # tuple 배열은 배열인데 값을 바꿀 수 없는 배열
# Out:
# (10, 11.4)

# %%
a
b
# Out:
# 11.4

# %%
c = None

# %%
print(a, b, c)
# Out:
# 10 11.4 None

# %%
print(type(a), type(b), type(c))
# Out:
# <class 'int'> <class 'float'> <class 'NoneType'>

# %%
c = a > b
print(c, type(c))
# Out:
# False <class 'bool'>

# %%
a = 'hello_world'

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(a, a[0], a[3], a[-1], a[10], a[-3])
# Out:
# hello_world h l d d r
